# %% [raw]
# ---
# title: "Sistema de Detección Temprana de Señales de Riesgo Académico y Bienestar
# Estudiantil en Textos Educativos"
# subtitle: "Proyecto de Estructuras de Datos y Algoritmos II"
# author:
#   - "Jhon Solorzano"
#   - "Deysi Guachamin"
#   - "Said Bravo"
#
# date: 2026-07-24
#
# lang: es
# bibliography: ref.bib
#
# format:
#   pdf:
#     toc: true
#     toc-title: "Índice de contenidos"
#     number-sections: false
#     geometry:
#       - top=2.5cm
#       - bottom=2.5cm
#       - left=3cm
#       - right=3cm
#     include-in-header:
#       text: |
#         \usepackage{graphicx}
#         \usepackage{titling}
#
# titlepage: true
#
# header-includes:
#   - |
#     \pretitle{
#       \begin{center}
#       \includegraphics[width=5cm]{epn.png}\\[1cm]
#       \Large
#       Escuela Politécnica Nacional\\[1cm]
#     }
#   - |
#     \posttitle{
#       \end{center}
#     }
#
# ---

# %% [markdown]
# # Introducción

# %% [markdown]
# # Descripción del Problema
# - Contexto:
# - Problemática:

# %% [markdown]
# # Motivación
# (Justificar el porqué de la herramienta. Resaltar la importancia de brindar un soporte preventivo a los departamentos de consejería o bienestar estudiantil para mitigar la deserción escolar a tiempo, especialmente en entornos de alta exigencia).

# %% [markdown]
# # Objetivos
# - Objetivo General:
# - Objetivos Específicos:

# %% [markdown]
# # Diseño general de la solución
# (Describir la arquitectura del software. Explicar el flujo del programa: el backend desarrollado en Python con Flask lee de forma asincrónica los archivos planos locales, ejecuta la normalización de texto, procesa las cadenas con los dos algoritmos y envía las variables de respuesta al diseño web interactivo en HTML y CSS).

# %% [markdown]
# # Conjunto de Patrones
# (Insertar aquí la tabla resumen o una muestra representativa de los 61 patrones incluidos en el archivo patrones_alerta_estudiantil.csv, detallando las columnas de Patrón, Categoría, Nivel de Alerta y la Sugerencia de Acción correspondiente).

# %% [markdown]
# # Descripción de los Algoritmos KMP y Boyer-Moore
#
# ## Algoritmo Knuth-Morris-Pratt (KMP):
#
# ## Algoritmo Boyer-Moore:

# %% [markdown]
# # Implementación y Flujo del Sistema
# (Colocar fragmentos del código fuente de las funciones principales en Python, detallando la lógica de limpieza realizada por la función de normalización antes de alimentar las funciones de búsqueda exacta).

# %% [markdown]
# # Pruebas Realizadas y Capturas de Pantalla
# (Tomar capturas de pantalla de la tabla resultante en el navegador web al presionar el botón de ejecución. Mostrar cómo el sistema lista de forma ordenada los mensajes procesados de nuestro archivo mensajes.txt).

# %% [markdown]
# # Comparación de Resultados
# (Presentar una tabla con una muestra de las 20 pruebas obligatorias ejecutadas en paralelo, exponiendo el ID, el mensaje de entrada, el patrón buscado, si fue detectado o no, las posiciones exactas encontradas por cada algoritmo y la velocidad precisa calculada por el cronómetro en milisegundos).

# %% [markdown]
# # Mockups del Sistema
# (Pegar aquí los esquemas visuales o capturas de pantalla de la interfaz web maquetada, justificando la presencia de las secciones de inicio, estado de los archivos de origen, panel de ejecución, tarjetas de estadísticas y la visualización de sugerencias de acción).

# %% [markdown]
# # Limitaciones de KMP y Boyer-Moore

# %% [markdown]
# # Posibles Mejoras con Inteligencia Artificial o NLP

# %% [markdown]
# # Impacto Ético y Social

# %% [markdown]
# # Declaración de Uso Responsable de IA

# %% [markdown]
# # Conclusiones

# %% [markdown]
# # Referencias
